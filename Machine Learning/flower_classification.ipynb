# %%
#IMPORTING NECESSARY LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#IMPORTING THE NECESSARY SCIKIT LEARN ELEMENTS
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing

# %%
#IMPORTING THE DATASET
from sklearn.datasets import load_iris

# %%
from sklearn.datasets import load_iris
import pandas as pd

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = [data.target_names[i] for i in data.target]

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
#DATA ANALYSIS
df.shape
# Out:
# (150, 5)

# %%
df['target'].value_counts()
# Out:
# target
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, np.str_('setosa')],
#        [4.9, 3.0, 1.4, 0.2, np.str_('setosa')],
#        [4.7, 3.2, 1.3, 0.2, np.str_('setosa')],
#        [4.6, 3.1, 1.5, 0.2, np.str_('setosa')],
#        [5.0, 3.6, 1.4, 0.2, np.str_('setosa')],
#        [5.4, 3.9, 1.7, 0.4, np.str_('setosa')],
#        [4.6, 3.4, 1.4, 0.3, np.str_('setosa')],
#        [5.0, 3.4, 1.5, 0.2, np.str_('setosa')],
#        [4.4, 2.9, 1.4, 0.2, np.str_('setosa')],
#        [4.9, 3.1, 1.5, 0.1, np.str_('setosa')],
#        [5.4, 3.7, 1.5, 0.2, np.str_('setosa')],
#        [4.8, 3.4, 1.6, 0.2, np.str_('setosa')],
#        [4.8, 3.0, 1.4, 0.1, np.str_('setosa')],
#        [4.3, 3.0, 1.1, 0.1, np.str_('setosa')],
#        [5.8, 4.0, 1.2, 0.2, np.str_('setosa')],
#        [5.7, 4.4, 1.5, 0.4, np.str_('setosa')],
#        [5.4, 3.9, 1.3, 0.4, np.str_('setosa')],
#        [5.1, 3.5, 1.4, 0.3, np.str_('setosa')],
#        [5.7, 3.8, 1.7, 0.3, np.str_('setosa')],
#        [5.1, 3.8, 1.5, 0.3, np.str_('setosa')],
#        [5.4, 3.4, 1.7, 0.2, np.str_('setosa')],
#        [5.1, 3.7, 1.5, 0.4, np.str_('setosa')],
#        [4.6, 3.6, 1.0, 0.2, np.str_('setosa')],
#        [5.1, 3.3, 1.7, 0.5, np.str_('setosa')],
#        [4.8, 3.4, 1.9, 0.2, np.str_('setosa')],
#        [5.0, 3.0, 1.6, 0.2, np.str_('setosa')],
#        [5.0, 3.4, 1.6, 0.4, np.str_('setosa')],
#        [5.2, 3.5, 1.5, 0.2, np.str_('setosa')],
#        [5.2, 3.4, 1.4, 0.2, np.str_('setosa')],
#        [4.7, 3.2, 1.6, 0.2, np.str_('setosa')],
#        [4.8, 3.1, 1.6, 0.2, np.str_('setosa')],
#        [5.4, 3.4, 1.5, 0.4, np.str_('setosa')],
#        [5.2, 4.1, 1.5, 0.1, np.str_('setosa')],
#        [5.5, 4.2, 1.4, 0.2, np.str_('setosa')],
#        [4.9, 3.1, 1.5, 0.2, np.str_('setosa')],
#        [5.0, 3.2, 1.2, 0.2, np.str_('setosa')],
#        [5.5, 3.5, 1.3, 0.2, np.str_('setosa')],
#        [4.9, 3.6, 1.4, 0.1, np.str_('setosa')],
#        [4.4, 3.0, 1.3, 0.2, np.str_('setosa')],
#        [5.1, 3.4, 1.5, 0.2, np.str_('setosa')],
#        [5.0, 3.5, 1.3, 0.3, np.str_('setosa')],
#        [4.5, 2.3, 1.3, 0.3, np.str_('setosa')],
#        [4.4, 3.2, 1.3, 0.2, np.str_('setosa')],
#        [5.0, 3.5, 1.6, 0.6, np.str_('setosa')],
#        [5.1, 3.8, 1.9, 0.4, np.str_('setosa')],
#        [4.8, 3.0, 1.4, 0.3, np.str_('setosa')],
#        [5.1, 3.8, 1.6, 0.2, np.str_('setosa')],
#        [4.6, 3.2, 1.4, 0.2, np.str_('setosa')],
#        [5.3, 3.7, 1.5, 0.2, np.str_('setosa')],
#        [5.0, 3.3, 1.4, 0.2, np.str_('setosa')],
#        [7.0, 3.2, 4.7, 1.4, np.str_('versicolor')],
#        [6.4, 3.2, 4.5, 1.5, np.str_('versicolor')],
#        [6.9, 3.1, 4.9, 1.5, np.str_('versicolor')],
#        [5.5, 2.3, 4.0, 1.3, np.str_('versicolor')],
#        [6.5, 2.8, 4.6, 1.5, np.str_('versicolor')],
#        [5.7, 2.8, 4.5, 1.3, np.str_('versicolor')],
#        [6.3, 3.3, 4.7, 1.6, np.str_('versicolor')],
#        [4.9, 2.4, 3.3, 1.0, np.str_('versicolor')],
#        [6.6, 2.9, 4.6, 1.3, np.str_('versicolor')],
#        [5.2, 2.7, 3.9, 1.4, np.str_('versicolor')],
#        [5.0, 2.0, 3.5, 1.0, np.str_('versicolor')],
#        [5.9, 3.0, 4.2, 1.5, np.str_('versicolor')],
#        [6.0, 2.2, 4.0, 1.0, np.str_('versicolor')],
#        [6.1, 2.9, 4.7, 1.4, np.str_('versicolor')],
#        [5.6, 2.9, 3.6, 1.3, np.str_('versicolor')],
#        [6.7, 3.1, 4.4, 1.4, np.str_('versicolor')],
#        [5.6, 3.0, 4.5, 1.5, np.str_('versicolor')],
#        [5.8, 2.7, 4.1, 1.0, np.str_('versicolor')],
#        [6.2, 2.2, 4.5, 1.5, np.str_('versicolor')],
#        [5.6, 2.5, 3.9, 1.1, np.str_('versicolor')],
#        [5.9, 3.2, 4.8, 1.8, np.str_('versicolor')],
#        [6.1, 2.8, 4.0, 1.3, np.str_('versicolor')],
#        [6.3, 2.5, 4.9, 1.5, np.str_('versicolor')],
#        [6.1, 2.8, 4.7, 1.2, np.str_('versicolor')],
#        [6.4, 2.9, 4.3, 1.3, np.str_('versicolor')],
#        [6.6, 3.0, 4.4, 1.4, np.str_('versicolor')],
#        [6.8, 2.8, 4.8, 1.4, np.str_('versicolor')],
#        [6.7, 3.0, 5.0, 1.7, np.str_('versicolor')],
#        [6.0, 2.9, 4.5, 1.5, np.str_('versicolor')],
#        [5.7, 2.6, 3.5, 1.0, np.str_('versicolor')],
#        [5.5, 2.4, 3.8, 1.1, np.str_('versicolor')],
#        [5.5, 2.4, 3.7, 1.0, np.str_('versicolor')],
#        [5.8, 2.7, 3.9, 1.2, np.str_('versicolor')],
#        [6.0, 2.7, 5.1, 1.6, np.str_('versicolor')],
#        [5.4, 3.0, 4.5, 1.5, np.str_('versicolor')],
#        [6.0, 3.4, 4.5, 1.6, np.str_('versicolor')],
#        [6.7, 3.1, 4.7, 1.5, np.str_('versicolor')],
#        [6.3, 2.3, 4.4, 1.3, np.str_('versicolor')],
#        [5.6, 3.0, 4.1, 1.3, np.str_('versicolor')],
#        [5.5, 2.5, 4.0, 1.3, np.str_('versicolor')],
#        [5.5, 2.6, 4.4, 1.2, np.str_('versicolor')],
#        [6.1, 3.0, 4.6, 1.4, np.str_('versicolor')],
#        [5.8, 2.6, 4.0, 1.2, np.str_('versicolor')],
#        [5.0, 2.3, 3.3, 1.0, np.str_('versicolor')],
#        [5.6, 2.7, 4.2, 1.3, np.str_('versicolor')],
#        [5.7, 3.0, 4.2, 1.2, np.str_('versicolor')],
#        [5.7, 2.9, 4.2, 1.3, np.str_('versicolor')],
#        [6.2, 2.9, 4.3, 1.3, np.str_('versicolor')],
#        [5.1, 2.5, 3.0, 1.1, np.str_('versicolor')],
#        [5.7, 2.8, 4.1, 1.3, np.str_('versicolor')],
#        [6.3, 3.3, 6.0, 2.5, np.str_('virginica')],
#        [5.8, 2.7, 5.1, 1.9, np.str_('virginica')],
#        [7.1, 3.0, 5.9, 2.1, np.str_('virginica')],
#        [6.3, 2.9, 5.6, 1.8, np.str_('virginica')],
#        [6.5, 3.0, 5.8, 2.2, np.str_('virginica')],
#        [7.6, 3.0, 6.6, 2.1, np.str_('virginica')],
#        [4.9, 2.5, 4.5, 1.7, np.str_('virginica')],
#        [7.3, 2.9, 6.3, 1.8, np.str_('virginica')],
#        [6.7, 2.5, 5.8, 1.8, np.str_('virginica')],
#        [7.2, 3.6, 6.1, 2.5, np.str_('virginica')],
#        [6.5, 3.2, 5.1, 2.0, np.str_('virginica')],
#        [6.4, 2.7, 5.3, 1.9, np.str_('virginica')],
#        [6.8, 3.0, 5.5, 2.1, np.str_('virginica')],
#        [5.7, 2.5, 5.0, 2.0, np.str_('virginica')],
#        [5.8, 2.8, 5.1, 2.4, np.str_('virginica')],
#        [6.4, 3.2, 5.3, 2.3, np.str_('virginica')],
#        [6.5, 3.0, 5.5, 1.8, np.str_('virginica')],
#        [7.7, 3.8, 6.7, 2.2, np.str_('virginica')],
#        [7.7, 2.6, 6.9, 2.3, np.str_('virginica')],
#        [6.0, 2.2, 5.0, 1.5, np.str_('virginica')],
#        [6.9, 3.2, 5.7, 2.3, np.str_('virginica')],
#        [5.6, 2.8, 4.9, 2.0, np.str_('virginica')],
#        [7.7, 2.8, 6.7, 2.0, np.str_('virginica')],
#        [6.3, 2.7, 4.9, 1.8, np.str_('virginica')],
#        [6.7, 3.3, 5.7, 2.1, np.str_('virginica')],
#        [7.2, 3.2, 6.0, 1.8, np.str_('virginica')],
#        [6.2, 2.8, 4.8, 1.8, np.str_('virginica')],
#        [6.1, 3.0, 4.9, 1.8, np.str_('virginica')],
#        [6.4, 2.8, 5.6, 2.1, np.str_('virginica')],
#        [7.2, 3.0, 5.8, 1.6, np.str_('virginica')],
#        [7.4, 2.8, 6.1, 1.9, np.str_('virginica')],
#        [7.9, 3.8, 6.4, 2.0, np.str_('virginica')],
#        [6.4, 2.8, 5.6, 2.2, np.str_('virginica')],
#        [6.3, 2.8, 5.1, 1.5, np.str_('virginica')],
#        [6.1, 2.6, 5.6, 1.4, np.str_('virginica')],
#        [7.7, 3.0, 6.1, 2.3, np.str_('virginica')],
#        [6.3, 3.4, 5.6, 2.4, np.str_('virginica')],
#        [6.4, 3.1, 5.5, 1.8, np.str_('virginica')],
#        [6.0, 3.0, 4.8, 1.8, np.str_('virginica')],
#        [6.9, 3.1, 5.4, 2.1, np.str_('virginica')],
#        [6.7, 3.1, 5.6, 2.4, np.str_('virginica')],
#        [6.9, 3.1, 5.1, 2.3, np.str_('virginica')],
#        [5.8, 2.7, 5.1, 1.9, np.str_('virginica')],
#        [6.8, 3.2, 5.9, 2.3, np.str_('virginica')],
#        [6.7, 3.3, 5.7, 2.5, np.str_('virginica')],
#        [6.7, 3.0, 5.2, 2.3, np.str_('virginica')],
#        [6.3, 2.5, 5.0, 1.9, np.str_('virginica')],
#        [6.5, 3.0, 5.2, 2.0, np.str_('virginica')],
#        [6.2, 3.4, 5.4, 2.3, np.str_('virginica')],
#        [5.9, 3.0, 5.1, 1.8, np.str_('virginica')]], dtype=object)

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]>

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#SPLITTING THE DATASET
x = df.iloc[:,:4]
y = df.iloc[:,-1]

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: target, Length: 150, dtype: object

# %%
#DATA NORMALIZATION
x = preprocessing.StandardScaler().fit_transform(x)
x
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00,  7.88807586e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.44707648e+00],
#        [-1.87002413e+00, -1.31979479e-01, -1.51073881e+00,
#         -1.44707648e+00],
#        [-5.25060772e-02,  2.16998818e+00, -1.45390138e+00,
#         -1.31544430e+00],
#        [-1.73673948e-01,  3.09077525e+00, -1.28338910e+00,
#         -1.05217993e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.39706395e+00,
#         -1.05217993e+00],
#        [-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.73673948e-01,  1.70959465e+00, -1.16971425e+00,
#         -1.18381211e+00],
#        [-9.00681170e-01,  1.70959465e+00, -1.28338910e+00,
#         -1.18381211e+00],
#        [-5.37177559e-01,  7.88807586e-01, -1.16971425e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  1.24920112e+00, -1.56757623e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  5.58610819e-01, -1.16971425e+00,
#         -9.20547742e-01],
#        [-1.26418478e+00,  7.88807586e-01, -1.05603939e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00, -1.31979479e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.22655167e+00,
#         -1.05217993e+00],
#        [-7.79513300e-01,  1.01900435e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-7.79513300e-01,  7.88807586e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.26418478e+00,  9.82172869e-02, -1.22655167e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  7.88807586e-01, -1.28338910e+00,
#         -1.05217993e+00],
#        [-7.79513300e-01,  2.40018495e+00, -1.28338910e+00,
#         -1.44707648e+00],
#        [-4.16009689e-01,  2.63038172e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  3.28414053e-01, -1.45390138e+00,
#         -1.31544430e+00],
#        [-4.16009689e-01,  1.01900435e+00, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.44707648e+00],
#        [-1.74885626e+00, -1.31979479e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-9.00681170e-01,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.01900435e+00, -1.39706395e+00,
#         -1.18381211e+00],
#        [-1.62768839e+00, -1.74335684e+00, -1.39706395e+00,
#         -1.18381211e+00],
#        [-1.74885626e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.01900435e+00, -1.22655167e+00,
#         -7.88915558e-01],
#        [-9.00681170e-01,  1.70959465e+00, -1.05603939e+00,
#         -1.05217993e+00],
#        [-1.26418478e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-9.00681170e-01,  1.70959465e+00, -1.22655167e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  3.28414053e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-6.58345429e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  5.58610819e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [ 1.40150837e+00,  3.28414053e-01,  5.35408562e-01,
#          2.64141916e-01],
#        [ 6.74501145e-01,  3.28414053e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [ 1.28034050e+00,  9.82172869e-02,  6.49083415e-01,
#          3.95774101e-01],
#        [-4.16009689e-01, -1.74335684e+00,  1.37546573e-01,
#          1.32509732e-01],
#        [ 7.95669016e-01, -5.92373012e-01,  4.78571135e-01,
#          3.95774101e-01],
#        [-1.73673948e-01, -5.92373012e-01,  4.21733708e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01,  5.58610819e-01,  5.35408562e-01,
#          5.27406285e-01],
#        [-1.14301691e+00, -1.51316008e+00, -2.60315415e-01,
#         -2.62386821e-01],
#        [ 9.16836886e-01, -3.62176246e-01,  4.78571135e-01,
#          1.32509732e-01],
#        [-7.79513300e-01, -8.22569778e-01,  8.07091462e-02,
#          2.64141916e-01],
#        [-1.02184904e+00, -2.43394714e+00, -1.46640561e-01,
#         -2.62386821e-01],
#        [ 6.86617933e-02, -1.31979479e-01,  2.51221427e-01,
#          3.95774101e-01],
#        [ 1.89829664e-01, -1.97355361e+00,  1.37546573e-01,
#         -2.62386821e-01],
#        [ 3.10997534e-01, -3.62176246e-01,  5.35408562e-01,
#          2.64141916e-01],
#        [-2.94841818e-01, -3.62176246e-01, -8.98031345e-02,
#          1.32509732e-01],
#        [ 1.03800476e+00,  9.82172869e-02,  3.64896281e-01,
#          2.64141916e-01],
#        [-2.94841818e-01, -1.31979479e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [-5.25060772e-02, -8.22569778e-01,  1.94384000e-01,
#         -2.62386821e-01],
#        [ 4.32165405e-01, -1.97355361e+00,  4.21733708e-01,
#          3.95774101e-01],
#        [-2.94841818e-01, -1.28296331e+00,  8.07091462e-02,
#         -1.30754636e-01],
#        [ 6.86617933e-02,  3.28414053e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 3.10997534e-01, -5.92373012e-01,  1.37546573e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01, -1.28296331e+00,  6.49083415e-01,
#          3.95774101e-01],
#        [ 3.10997534e-01, -5.92373012e-01,  5.35408562e-01,
#          8.77547895e-04],
#        [ 6.74501145e-01, -3.62176246e-01,  3.08058854e-01,
#          1.32509732e-01],
#        [ 9.16836886e-01, -1.31979479e-01,  3.64896281e-01,
#          2.64141916e-01],
#        [ 1.15917263e+00, -5.92373012e-01,  5.92245988e-01,
#          2.64141916e-01],
#        [ 1.03800476e+00, -1.31979479e-01,  7.05920842e-01,
#          6.59038469e-01],
#        [ 1.89829664e-01, -3.62176246e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [-1.73673948e-01, -1.05276654e+00, -1.46640561e-01,
#         -2.62386821e-01],
#        [-4.16009689e-01, -1.51316008e+00,  2.38717193e-02,
#         -1.30754636e-01],
#        [-4.16009689e-01, -1.51316008e+00, -3.29657076e-02,
#         -2.62386821e-01],
#        [-5.25060772e-02, -8.22569778e-01,  8.07091462e-02,
#          8.77547895e-04],
#        [ 1.89829664e-01, -8.22569778e-01,  7.62758269e-01,
#          5.27406285e-01],
#        [-5.37177559e-01, -1.31979479e-01,  4.21733708e-01,
#          3.95774101e-01],
#        [ 1.89829664e-01,  7.88807586e-01,  4.21733708e-01,
#          5.27406285e-01],
#        [ 1.03800476e+00,  9.82172869e-02,  5.35408562e-01,
#          3.95774101e-01],
#        [ 5.53333275e-01, -1.74335684e+00,  3.64896281e-01,
#          1.32509732e-01],
#        [-2.94841818e-01, -1.31979479e-01,  1.94384000e-01,
#          1.32509732e-01],
#        [-4.16009689e-01, -1.28296331e+00,  1.37546573e-01,
#          1.32509732e-01],
#        [-4.16009689e-01, -1.05276654e+00,  3.64896281e-01,
#          8.77547895e-04],
#        [ 3.10997534e-01, -1.31979479e-01,  4.78571135e-01,
#          2.64141916e-01],
#        [-5.25060772e-02, -1.05276654e+00,  1.37546573e-01,
#          8.77547895e-04],
#        [-1.02184904e+00, -1.74335684e+00, -2.60315415e-01,
#         -2.62386821e-01],
#        [-2.94841818e-01, -8.22569778e-01,  2.51221427e-01,
#          1.32509732e-01],
#        [-1.73673948e-01, -1.31979479e-01,  2.51221427e-01,
#          8.77547895e-04],
#        [-1.73673948e-01, -3.62176246e-01,  2.51221427e-01,
#          1.32509732e-01],
#        [ 4.32165405e-01, -3.62176246e-01,  3.08058854e-01,
#          1.32509732e-01],
#        [-9.00681170e-01, -1.28296331e+00, -4.30827696e-01,
#         -1.30754636e-01],
#        [-1.73673948e-01, -5.92373012e-01,  1.94384000e-01,
#          1.32509732e-01],
#        [ 5.53333275e-01,  5.58610819e-01,  1.27429511e+00,
#          1.71209594e+00],
#        [-5.25060772e-02, -8.22569778e-01,  7.62758269e-01,
#          9.22302838e-01],
#        [ 1.52267624e+00, -1.31979479e-01,  1.21745768e+00,
#          1.18556721e+00],
#        [ 5.53333275e-01, -3.62176246e-01,  1.04694540e+00,
#          7.90670654e-01],
#        [ 7.95669016e-01, -1.31979479e-01,  1.16062026e+00,
#          1.31719939e+00],
#        [ 2.12851559e+00, -1.31979479e-01,  1.61531967e+00,
#          1.18556721e+00],
#        [-1.14301691e+00, -1.28296331e+00,  4.21733708e-01,
#          6.59038469e-01],
#        [ 1.76501198e+00, -3.62176246e-01,  1.44480739e+00,
#          7.90670654e-01],
#        [ 1.03800476e+00, -1.28296331e+00,  1.16062026e+00,
#          7.90670654e-01],
#        [ 1.64384411e+00,  1.24920112e+00,  1.33113254e+00,
#          1.71209594e+00],
#        [ 7.95669016e-01,  3.28414053e-01,  7.62758269e-01,
#          1.05393502e+00],
#        [ 6.74501145e-01, -8.22569778e-01,  8.76433123e-01,
#          9.22302838e-01],
#        [ 1.15917263e+00, -1.31979479e-01,  9.90107977e-01,
#          1.18556721e+00],
#        [-1.73673948e-01, -1.28296331e+00,  7.05920842e-01,
#          1.05393502e+00],
#        [-5.25060772e-02, -5.92373012e-01,  7.62758269e-01,
#          1.58046376e+00],
#        [ 6.74501145e-01,  3.28414053e-01,  8.76433123e-01,
#          1.44883158e+00],
#        [ 7.95669016e-01, -1.31979479e-01,  9.90107977e-01,
#          7.90670654e-01],
#        [ 2.24968346e+00,  1.70959465e+00,  1.67215710e+00,
#          1.31719939e+00],
#        [ 2.24968346e+00, -1.05276654e+00,  1.78583195e+00,
#          1.44883158e+00],
#        [ 1.89829664e-01, -1.97355361e+00,  7.05920842e-01,
#          3.95774101e-01],
#        [ 1.28034050e+00,  3.28414053e-01,  1.10378283e+00,
#          1.44883158e+00],
#        [-2.94841818e-01, -5.92373012e-01,  6.49083415e-01,
#          1.05393502e+00],
#        [ 2.24968346e+00, -5.92373012e-01,  1.67215710e+00,
#          1.05393502e+00],
#        [ 5.53333275e-01, -8.22569778e-01,  6.49083415e-01,
#          7.90670654e-01],
#        [ 1.03800476e+00,  5.58610819e-01,  1.10378283e+00,
#          1.18556721e+00],
#        [ 1.64384411e+00,  3.28414053e-01,  1.27429511e+00,
#          7.90670654e-01],
#        [ 4.32165405e-01, -5.92373012e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 3.10997534e-01, -1.31979479e-01,  6.49083415e-01,
#          7.90670654e-01],
#        [ 6.74501145e-01, -5.92373012e-01,  1.04694540e+00,
#          1.18556721e+00],
#        [ 1.64384411e+00, -1.31979479e-01,  1.16062026e+00,
#          5.27406285e-01],
#        [ 1.88617985e+00, -5.92373012e-01,  1.33113254e+00,
#          9.22302838e-01],
#        [ 2.49201920e+00,  1.70959465e+00,  1.50164482e+00,
#          1.05393502e+00],
#        [ 6.74501145e-01, -5.92373012e-01,  1.04694540e+00,
#          1.31719939e+00],
#        [ 5.53333275e-01, -5.92373012e-01,  7.62758269e-01,
#          3.95774101e-01],
#        [ 3.10997534e-01, -1.05276654e+00,  1.04694540e+00,
#          2.64141916e-01],
#        [ 2.24968346e+00, -1.31979479e-01,  1.33113254e+00,
#          1.44883158e+00],
#        [ 5.53333275e-01,  7.88807586e-01,  1.04694540e+00,
#          1.58046376e+00],
#        [ 6.74501145e-01,  9.82172869e-02,  9.90107977e-01,
#          7.90670654e-01],
#        [ 1.89829664e-01, -1.31979479e-01,  5.92245988e-01,
#          7.90670654e-01],
#        [ 1.28034050e+00,  9.82172869e-02,  9.33270550e-01,
#          1.18556721e+00],
#        [ 1.03800476e+00,  9.82172869e-02,  1.04694540e+00,
#          1.58046376e+00],
#        [ 1.28034050e+00,  9.82172869e-02,  7.62758269e-01,
#          1.44883158e+00],
#        [-5.25060772e-02, -8.22569778e-01,  7.62758269e-01,
#          9.22302838e-01],
#        [ 1.15917263e+00,  3.28414053e-01,  1.21745768e+00,
#          1.44883158e+00],
#        [ 1.03800476e+00,  5.58610819e-01,  1.10378283e+00,
#          1.71209594e+00],
#        [ 1.03800476e+00, -1.31979479e-01,  8.19595696e-01,
#          1.44883158e+00],
#        [ 5.53333275e-01, -1.28296331e+00,  7.05920842e-01,
#          9.22302838e-01],
#        [ 7.95669016e-01, -1.31979479e-01,  8.19595696e-01,
#          1.05393502e+00],
#        [ 4.32165405e-01,  7.88807586e-01,  9.33270550e-01,
#          1.44883158e+00],
#        [ 6.86617933e-02, -1.31979479e-01,  7.62758269e-01,
#          7.90670654e-01]])

# %%
#TRAIN TEST SPLIT
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
# MODEL BUILDING AND PREDICTION
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predict = knn.predict(x_test)

# %%
# ACCURACY
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test.values,y_predict)

# %%
accuracy
# Out:
# 0.9666666666666667
